# %%
import pandas as pd
data = {"A": 41, "C": 33, "G":22, "T": 44}
df_data = {"base":data.keys(), "count":data.values()}
df = pd.DataFrame(df_data)
print(df)

df.plot(kind="bar", x="base", y="count", title = "base count", xlabel = "Base", ylabel = "Count")
# Out:
#   base  count
# 0    A     41
# 1    C     33
# 2    G     22
# 3    T     44
# <Axes: title={'center': 'base count'}, xlabel='Base', ylabel='Count'>

# %%
from Bio import SeqIO

record = SeqIO.parse("NC_045512.gb", "genebank")
print(record)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from Bio import SeqIO
# ----> 3 record = SeqIO.parse("NC_045512.gb", "genebank")
#       4 print(record)
#
# File c:\Users\gjrms\miniconda3\Lib\site-packages\Bio\SeqIO\__init__.py:629, in parse(handle, format, alphabet)
#     626 if format in AlignIO._FormatToIterator:
#     627     # Use Bio.AlignIO to read in the alignments
#     628     return (r for alignment in AlignIO.parse(handle, format) for r in alignment)
# --> 629 raise ValueError(f"Unknown format '{format}'")
#
# ValueError: Unknown format 'genebank'
